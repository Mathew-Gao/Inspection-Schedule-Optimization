# %% [markdown]
# #### Calculate Distance Matrix

# %%
from collections import defaultdict
import pandas as pd
import requests
import json 

#solve module 'numpy' has no attribute 'ndarray'
import numpy as np
import math

# %%
def get_tasks(file: str, depot_coords: tuple, sheet: str):
    '''Processes a tasks Excel sheet into a JSON format for a POST request payload.
    Required format of the Bing REST API is a dictionary of origin and locations, where the value is another dictionary of the latitude and longitude.'''
    df = pd.read_excel(f"./{file}", sheet_name=sheet)
    #pointnum is the 10th column in excel sheet
    pointnum=int(df.columns[10])
    tasks_df = df.iloc[0:pointnum][:]
    n=len(tasks_df)
    locations = dict() 

    locations["origins"] = []
    locations["destinations"] = []
    locations["travelMode"] = "driving"


    # Adding depot location as location 0
    locations["origins"].append({"longitude": depot_coords[0], "latitude": depot_coords[1]})
    locations["destinations"].append({"longitude": depot_coords[0], "latitude": depot_coords[1]})

    for index, row in tasks_df.iterrows():
        if index in range(n):
            locations["origins"].append({"longitude": row['Longtitude'], "latitude": row['Latitude']})
            locations["destinations"].append({"longitude": row['Longtitude'], "latitude": row['Latitude']})
    return n, locations

# %%
def distance_matrix(response: requests.Response):
    '''Process the reponse to get the distance matrix.'''
    results = response.json()["resourceSets"][0]["resources"][0]["results"]
    n = int(math.sqrt(len(results)))
    
    matrix = [[np.Inf for i in range(n)] for j in range(n)]
    for entry in results:
        matrix[entry["originIndex"]][entry["destinationIndex"]] = entry["travelDistance"]
    
    return matrix

# %%
api_key = "Ag0unjZ8eW7hV91G8dXRk2Qf9Sk_GEIltJ9zLxdnwlP-s5wcZUQ1Q9x2yquA0eFf"
url = "https://dev.virtualearth.net/REST/v1/Routes/DistanceMatrix?key="+api_key
headers = {'Content-Type': 'application/json'} 


# Shepparton
n1, cluster1 = get_tasks("shepp_cluster.xlsx", (145.41880628382472, -36.37819524436343), "cluster 1")
response1 = requests.post(url, headers=headers, data=json.dumps(cluster1))

n2, cluster2 = get_tasks("shepp_cluster.xlsx", (145.41880628382472, -36.37819524436343), "cluster 2")
response2 = requests.post(url, headers=headers, data=json.dumps(cluster2))

n3, cluster3 = get_tasks("shepp_cluster.xlsx", (145.41880628382472, -36.37819524436343), "cluster 3")
response3 = requests.post(url, headers=headers, data=json.dumps(cluster3))

n4, cluster4 = get_tasks("shepp_cluster.xlsx", (145.41880628382472, -36.37819524436343), "cluster 4")
response4 = requests.post(url, headers=headers, data=json.dumps(cluster4))

# %%
col1 = []
for i in range(len(cluster1['origins'])):
     col1.append("({},{})".format(cluster1['origins'][i]['longitude'], cluster1['origins'][i]['latitude']))

col2 = []
for i in range(len(cluster2['origins'])):
     col2.append("({},{})".format(cluster2['origins'][i]['longitude'], cluster2['origins'][i]['latitude']))

col3 = []
for i in range(len(cluster3['origins'])):
     col3.append("({},{})".format(cluster3['origins'][i]['longitude'], cluster3['origins'][i]['latitude']))

col4 = []
for i in range(len(cluster4['origins'])):
     col4.append("({},{})".format(cluster4['origins'][i]['longitude'], cluster4['origins'][i]['latitude']))

# %%
dist_matrix1 = pd.DataFrame(distance_matrix(requests.post(url, headers=headers, data=json.dumps(cluster1))))
dist_matrix1.columns = col1
dist_matrix1 = dist_matrix1.set_index(pd.Index(col1))

dist_matrix2 = pd.DataFrame(distance_matrix(requests.post(url, headers=headers, data=json.dumps(cluster2))))
dist_matrix2.columns = col2
dist_matrix2 = dist_matrix2.set_index(pd.Index(col2))

dist_matrix3 = pd.DataFrame(distance_matrix(requests.post(url, headers=headers, data=json.dumps(cluster3))))
dist_matrix3.columns = col3
dist_matrix3 = dist_matrix3.set_index(pd.Index(col3))

dist_matrix4 = pd.DataFrame(distance_matrix(requests.post(url, headers=headers, data=json.dumps(cluster4))))
dist_matrix4.columns = col4
dist_matrix4 = dist_matrix4.set_index(pd.Index(col4))



dist_matrix_dict = {1:dist_matrix1, 2:dist_matrix2, 3:dist_matrix3, 4:dist_matrix4}
#dist_matrix_dict = {1:dist_matrix1, 2:dist_matrix2}

# %%
#read start point and end point to each road
#create a dictionary

df = pd.read_excel("shepp_coor_final_adjusted.xlsx", sheet_name="Sheet1")

# %%
road_coor = defaultdict()
road_dist = defaultdict()
for i, row in df.iterrows():
    start_coor = "({},{})".format(row["start_long"],row["start_lat"])
    end_coor = "({},{})".format(row["end_long"],row["end_lat"])
    road_coor[row["Inspection ID"]] = [start_coor, end_coor]
    road_dist[row["Inspection ID"]] = round(row['inspection km'],2)

# %%
shepp_cluster = defaultdict(list)
road_cat = defaultdict(list)
for i, row in df.iterrows():
    if isinstance(row['cluster'],str):
        cluster = [int(s) for s in row['cluster'].split() if s.isdigit()]
        for i in cluster:
            shepp_cluster[i].append(row['Inspection ID'])
    else:
        shepp_cluster[row['cluster']].append(row['Inspection ID'])
    road_cat[row['class']].append(row['Inspection ID'])

# %%
dist_matrix_dict[1].loc[road_coor['SHE_28'][0],road_coor['SHE_28'][1]]+\
dist_matrix_dict[1].loc['(145.41880628382472,-36.37819524436343)', road_coor['SHE_28'][0]]
# Out:
# 45.681

# %%
def route_driving_distance(route, cluster):
    '''calculate total driving distance of route'''
    total_dist = 0
    pre_point = '(145.41880628382472,-36.37819524436343)'
    end_point = '(145.41880628382472,-36.37819524436343)'
    locs=[pre_point]
    for k in route:
        start = road_coor[k][0]
        end = road_coor[k][1]
        forward = dist_matrix_dict[cluster].loc[pre_point, start] +dist_matrix_dict[cluster].loc[start, end]
        backward = dist_matrix_dict[cluster].loc[pre_point, end] +dist_matrix_dict[cluster].loc[end, start]
        if forward < backward:
            pre_point = end
            total_dist += forward
            locs.append(start)
            locs.append(end)

        else:
            pre_point = start
            total_dist += backward
            locs.append(end)
            locs.append(start)
    total_dist = total_dist + dist_matrix_dict[cluster].loc[pre_point, end_point]
    locs.append(end_point)
    
    return total_dist,locs

# %%
def comb_inspection_distance(comb):
    '''calculate inspection distance of a road combination'''
    inspection_dist = 0
    for k in comb:
        inspection_dist += road_dist[k]
    return inspection_dist

# %%
from itertools import combinations, permutations

def shortest_distance(cluster: int):
    '''calculate the shortest driving distance for each possible scenario of road inspection within 
    a particular cluster'''
    shortest_distance = defaultdict(list)
    for i in range(1,len(shepp_cluster[cluster])+1):
        road_scenario = combinations(shepp_cluster[cluster],i)
        for j in road_scenario:
            route_perm = permutations(j)
            total_dist_dict = defaultdict(float)
            coordinates=defaultdict(list)
            inspect_dist = comb_inspection_distance(j)
            if inspect_dist <= 140 and inspect_dist >= 80:
                for route in list(route_perm):
                    dist,locations = route_driving_distance(route, cluster)
                    total_dist_dict[route] = dist
                    coordinates[route] = locations
                if min(total_dist_dict.values())<=300:
                    key_list = list(total_dist_dict.keys())
                    val_list = list(total_dist_dict.values())
                    position = val_list.index(min(total_dist_dict.values()))
                    shortest_route = key_list[position]
                    shortest_distance[str(j)] = [min(total_dist_dict.values()),inspect_dist, shortest_route, coordinates[shortest_route]]
    
    return shortest_distance

# %%
dist_c1 = shortest_distance(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/kuan/Desktop/Downer Project Final/Optimize Routes.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> dist_c1 = shortest_distance(1)
#
# /Users/kuan/Desktop/Downer Project Final/Optimize Routes.ipynb Cell 16 in shortest_distance(cluster)
#      <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X22sZmlsZQ%3D%3D?line=13'>14</a> if inspect_dist <= 140 and inspect_dist >= 80:
#      <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X22sZmlsZQ%3D%3D?line=14'>15</a>     for route in list(route_perm):
# ---> <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X22sZmlsZQ%3D%3D?line=15'>16</a>         dist,locations = route_driving_distance(route, cluster)
#      <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X22sZmlsZQ%3D%3D?line=16'>17</a>         total_dist_dict[route] = dist
#      <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X22sZmlsZQ%3D%3D?line=17'>18</a>         coordinates[route] = locations
#
# /Users/kuan/Desktop/Downer Project Final/Optimize Routes.ipynb Cell 16 in route_driving_distance(route, cluster)
#       <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a> start = road_coor[k][0]
#       <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X22sZmlsZQ%3D%3D?line=8'>9</a> end = road_coor[k][1]
# ---> <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X22sZmlsZQ%3D%3D?line=9'>10</a> forward = dist_matrix_dict[cluster].loc[pre_point, start] +dist_matrix_dict[cluster].loc[start, end]
#      <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X22sZmlsZQ%3D%3D?line=10'>11</a> backward = dist_matrix_dict[cluster].loc[pre_point, end] +dist_matrix_dict[cluster].loc[end, start]
#      <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X22sZmlsZQ%3D%3D?line=11'>12</a> if forward < backward:
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/indexing.py:959, in _LocationIndexer.__getitem__(self, key)
#     957 key = tuple(list(x) if is_iterator(x) else x for x in key)
#     958 key = tuple(com.apply_if_callable(x, self.obj) for x in key)
# --> 959 if self._is_scalar_access(key):
#     960     return self.obj._get_value(*key, takeable=self._takeable)
#     961 return self._getitem_tuple(key)
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/indexing.py:1040, in _LocIndexer._is_scalar_access(self, key)
#    1037 if not is_scalar(k):
#    1038     return False
# -> 1040 ax = self.obj.axes[i]
#    1041 if isinstance(ax, MultiIndex):
#    1042     return False
#
# KeyboardInterrupt:

# %%
#clear empty dicts
def clear_empty_value(dict):
    for k in list(dict.keys()):
        if not dict[k]:
            del dict[k]
    return dict

# %%
dist_c2 = shortest_distance(2)

# %%
dist_c3 = shortest_distance(3)

# %%
dist_c4 = shortest_distance(4)

# %%
#define a dictionary that store which road combination beglongs to which cluster
comb_cluster_dict = {1:dist_c1.keys(), 2:dist_c2.keys(), 3:dist_c3.keys(), 4:dist_c4.keys()}

# %%
#get coords for ('SHE_01', 'SHE_07', 'SHE_26', 'SHE_04')
road_coor['SHE_01']+road_coor['SHE_07']+road_coor['SHE_26']+road_coor['SHE_04']
# Out:
# ['(145.376957,-36.518167)',
#  '(145.399107,-36.381874)',
#  '(145.388727,-36.440749)',
#  '(145.431021,-36.303724)',
#  '(145.461966,-36.36458)',
#  '(145.68616,-36.327422)',
#  '(145.399244,-36.381019)',
#  '(145.708043,-36.417435)']

# %%
dist_c1[('SHE_01', 'SHE_04', 'SHE_07', 'SHE_26')]
# Out:
# []

# %%
dist_c1 = clear_empty_value(dist_c1)
dist_c2 = clear_empty_value(dist_c2)
dist_c3 = clear_empty_value(dist_c3)
dist_c4 = clear_empty_value(dist_c4)

# %%
pre_point='(145.41880628382472,-36.37819524436343)'

# %%
comb_distance = defaultdict()
comb_inspect = defaultdict()
comb_locations=defaultdict()

for dic in [dist_c1, dist_c2, dist_c3, dist_c4]:
    for key in dic:
        key = str(key)
        comb_distance[key] = dic[key][0]
        comb_inspect[key] = dic[key][1]
        loc=[]
        for a in (dic[key][3]):
            if(type(a)==str):
                latitude=round(float(a.split(",")[1][:-1]),5)
                longitude=round(float(a.split(",")[0][1:]),5)
            else:
                latitude=round(a[0],5)
                longitude=round(a[1],5)
            loc.append((latitude,longitude))
        comb_locations[key]=[dic[key][2],loc]

# %% [markdown]
# #### Model Formulation

# %%
from pulp import *
from gurobipy import *

# %%
#check available solvers
print(listSolvers(onlyAvailable=True))
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-10-12
# No parameters matching '_test' found
# ['GUROBI', 'GUROBI_CMD', 'PULP_CBC_CMD']

# %%
road_comb = list(comb_distance.keys())
road_comb = [str(i) for i in road_comb]
road_id = list(df['Inspection ID'])
nweek = [1, 2, 3, 4]
ndays = [1, 2, 3, 4, 5]
clusters = [1, 2, 3, 4]

# %%
inspection_result=defaultdict(list)
total_driving_distance_result=defaultdict(list)
total_driving_distance_total_result=defaultdict(float)

# %%
dfs=[]
total_driving_distance_weight=[0,0.5,1,1.5,2,2.5,3,3.5,4]
for P in range(len(total_driving_distance_weight)):
    #create model
    m = Model('Inspection Scheduling')

    #initialise decision variables
    r = m.addVars(road_comb, nweek, ndays, vtype = GRB.BINARY, name = [[[f'r_{i}_{j}_{k}' for k in ndays] for j in nweek] for i in road_comb])

    c = m.addVars(clusters, nweek, ndays, vtype = GRB.BINARY, name = [[[f'c_{i}_{j}_{k}' for k in ndays] for j in nweek] for i in clusters] )

    z = m.addVars(road_id, vtype = GRB.BINARY, name = [f'z_{i}' for i in road_id])

    t = m.addVars(nweek, ndays[0:4], vtype = GRB.CONTINUOUS, name = [[f't_{j}_{k}' for k in range(1,5)] for j in nweek])

    wk= m.addVars(nweek)

    comb_dist_dict = defaultdict()
    comb_inspect_dict = defaultdict()
    for key in r:
        comb_dist_dict[key] = comb_distance[key[0]]
        comb_inspect_dict[key] = comb_inspect[key[0]]

    #add constraints

    #all road scenarios within a clutser will not occur if that cluster is not visited on a particular day
    for i in comb_cluster_dict:
        for j in nweek:
            for k in ndays:
                comb_sum = 0
                for comb in list(comb_cluster_dict[i]):
                    comb_sum += r.sum(comb, j, k)
                m.addConstr(comb_sum <= c.sum(i, j, k))

    #only one cluster is visted per day
    for j in nweek:
        for k in ndays:
            m.addConstr((c.sum('*', j, k) == 1), name= "one cluster per day")

    #RMC2
    road_rmc2 = road_cat[2]
    for road in road_rmc2:
        for j in nweek:
            sum1 = sum2 = sum3 = 0
            for comb in road_comb:
                if road in comb:
                    sum1 += r.sum(comb, j, 1) + r.sum(comb, j, 4)
                    sum2 += r.sum(comb, j, 2) + r.sum(comb, j, 5)
                    sum3 += r.sum(comb, j, 3)
            m.addConstr((sum1 == 2*z.sum(road)), name = "Monday and Thursday Inspection")
            m.addConstr((sum2 == 2 - 2*z.sum(road)), name = "Tuesday and Friday Inspection")
            m.addConstr((sum3 == 0), name = "no Wednesday Inspection")

    #RMC3
    road_rmc3 = road_cat[3]
    for road in road_rmc3:
        for k in ndays:
            week1 = week2 = week3 = week4 =0
            for comb in road_comb:
                if road in comb:
                    week1 += r.sum(comb, 1, k)
                    week2 += r.sum(comb, 2, k)
                    week3 += r.sum(comb, 3, k)
                    week4 += r.sum(comb, 4, k)
            m.addConstr(week1 == week2)
            m.addConstr(week2 == week3)
            m.addConstr(week3 == week4)
        for j in nweek:
            total = 0
            for comb in road_comb:
                if road in comb:
                    total += r.sum(comb, j, '*')
            m.addConstr((total == 1), name = "once a week")

    #RMC4
    road_rmc4 = road_cat[4]
    for road in road_rmc4:
        total1 = 0
        for k in ndays:
            w1 = w2 = w3 = w4 = 0
            for comb in road_comb:
                if road in comb:
                    w1 += r.sum(comb, 1, k)
                    w2 += r.sum(comb, 2, k)
                    w3 += r.sum(comb, 3, k)
                    w4 += r.sum(comb, 4, k)
            m.addConstr(w1 == w3)
            m.addConstr(w2 == w4)
        for comb in road_comb:
            if road in comb:
                total1 += r.sum(comb, '*','*')
        m.addConstr(total1 == 2, name = "once very two weeks")

    #RMC5
    road_rmc5 = road_cat[5]
    total2 = 0
    for road in road_rmc5:
        for comb in road_comb:
            if road in comb:
                total2 += r.sum(comb, '*','*')
        m.addConstr(total2 == 1, name = "once very four weeks")

    #each road cannot be inspected more than once on a day
    for road in road_id:
        for j in nweek:
            for k in ndays:
                sum4 = 0
                for comb in road_comb:
                    if road in comb:
                        sum4 += r.sum(comb,j,k)
                m.addConstr((sum4 <= 1), name = "each road cannot be inspect more than once")

    #absolute difference of inspection km between days
    for j in nweek:
        for k in ndays[0:4]:
            m.addConstr(t.sum(j,k) >= r.prod(comb_inspect_dict,'*',j,k+1)-r.prod(comb_inspect_dict,'*',j,k))
            m.addConstr(t.sum(j,k) >= r.prod(comb_inspect_dict,'*',j,k)-r.prod(comb_inspect_dict,'*',j,k+1))

    #absolute difference of inspection km between weeks
    m.addConstrs(wk.sum(j)>=(r.prod(comb_inspect_dict,'*',j+1,"*")-r.prod(comb_inspect_dict,'*',j,"*")) for j in nweek[0:3])
    m.addConstrs(wk.sum(j)>=(r.prod(comb_inspect_dict,'*',j,"*")-r.prod(comb_inspect_dict,'*',j+1,"*")) for j in nweek[0:3])

    #objective function
    obj_func = t.sum() + (wk.sum()) + total_driving_distance_weight[P]* r.prod(comb_dist_dict, '*', '*', '*')
   
    #############################################################################################################
    m.setObjective(obj_func, GRB.MINIMIZE)
    m.Params.MIPGap = 0.05
    m.Params.TimeLimit = 200
    m.optimize()

#############################################################################################################
    import re
    print('obj=', m.ObjVal)
    comb = []
    for v in m.getVars():
        if v.x>0 and v.varName.startswith('r'):
            print(v.varName, ':', v.x)
            res  = re.findall(r'\(.*?\)', v.varName)
            comb.append(res[0])
    #############################################################################################################
    final_dist = defaultdict()
    for i in comb:
        final_dist[i] = comb_distance[i]
    total_distance=0
    for key in comb:
        total_distance += comb_distance[key]

    from collections import defaultdict
    road_schedules = defaultdict(list)
    #############################################################################################################
    for v in m.getVars():
        if v.x>0 and v.varName.startswith('r'):
            #anything inside '()'
            roads  = re.findall(r'\(.*?\)', v.varName)
            road_list=roads[0][1:-1].split(",")
            week=(v.VarName[-4:][1])
            day=(v.VarName[-4:][3])
            for road in road_list:
            #Find road name inside '' 
                road_name=re.findall(r"'(.*?)'", road)[0]
                road_schedules[road_name].append((week,day))
#############################################################################################################
    cols=['  ']*2+['W1']+['  ']*2+['  ']*2+['W2']+['  ']*2+['  ']*2+['W3']+['  ']*2+['  ']*2+['W4']+['  ']*2
    df=pd.DataFrame(columns=cols,index=[['Roads/ Days']+[i for i in road_dist.keys()]])
    #set all values of df to 0
    df.iloc[0,:]=['[ day1','day2','day3','day4','day5  ]']*4
    df=df.fillna('')
    def get_index_num(df,road):
        if(road[-2]!='0'):
            row_index=int(road[-2:])
        else:
            row_index=int(road[-1])
        return row_index

    for road in road_schedules:
        for week,day in road_schedules[road]:
            col_index=(int(week)-1)*5+int(day)-1
            row_number=get_index_num(df,road)
            df.iloc[row_number,col_index]=road_dist[road]

#############################################################################################################
    df.loc['Daily_inspection'] = ''
    df.loc['Daily_driving_distance']=''
    df.loc['Daily visiting Locations (Shortest Distance route)'] =[list() for x in range(len(df.columns))]
    df.loc['Location Coordinates']=[list() for x in range(len(df.columns))]
    df
    # #loop through each column and sum the values
    for i in range(0,df.shape[1]):
    #     #loop through each row
        total=0
        for j in range(1,31):
            if(df.iloc[j,i]!=''):
                total+=df.iloc[j,i]
        df.iloc[df.index.get_loc('Daily_inspection'),i]=float(total)
        inspection_result[P].append(total)
    df=df.replace(0,'')
    # #change the row of total to 0 if it's blank
    for j in range(0,df.shape[1]):
        if(df.iloc[df.index.get_loc('Daily_inspection'),j]==''):
            df.iloc[df.index.get_loc('Daily_inspection'),j]=0
    pd.set_option('display.max_columns', None)
    # #sum up the all columns in df and put it in the last row of df
    # df.iloc[df.index.get_loc('Daily_inspection'),10]=df.iloc[-3].sum()


    for j in range(0,df.shape[1]):
        value_list=[]
        for i in range(1,31):
            if(df.iloc[i,j]!=''):
                if(i<=9):
                    value_list.append('0'+str(i))
                else:
                    value_list.append(str(i))
        route_list="\"("
        for each in value_list:
            if(each!=value_list[-1]):
                route_list+=('\'SHE_'+each+'\', ')
            else:
                route_list+=('\'SHE_'+each+'\')\"')
        #ignore the escaping character for route_list
        if(route_list!="\"("):
            route_list=eval(route_list)
            route_list=str((route_list))
        else:
            route_list=""
        if(route_list in comb_locations):
            Locations=comb_locations[route_list]
            df.iloc[df.index.get_loc('Daily visiting Locations (Shortest Distance route)'),j].append(Locations[0])
            df.iloc[df.index.get_loc('Location Coordinates'),j].append(Locations[1])

        else:
            Locations=["NA","NA"]
            df.iloc[df.index.get_loc('Daily visiting Locations (Shortest Distance route)'),j].append(Locations[0])
            df.iloc[df.index.get_loc('Location Coordinates'),j].append(Locations[1])
        if(route_list in final_dist):
            df.iloc[df.index.get_loc('Daily_driving_distance'),j]=final_dist[route_list]
        else:
            df.iloc[df.index.get_loc('Daily_driving_distance'),j]="NA"
        
    total_driving_distance_total_result[P]=total_distance
    dfs.append(df)
# Out:
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 1139 rows, 33491 columns and 793896 nonzeros
# Model fingerprint: 0x4ce3b96c
# Variable types: 20 continuous, 33471 integer (33471 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 642 rows and 3348 columns
# Presolve time: 1.00s
# Presolved: 497 rows, 30143 columns, 531950 nonzeros
# Variable types: 0 continuous, 30143 integer (30094 binary)
#
# Root relaxation: objective 0.000000e+00, 2783 iterations, 1.19 seconds (3.15 work units)
# Total elapsed time = 5.06s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0
: 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_29', 'SHE_30')_4_4 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_26', 'SHE_27', 'SHE_28')_1_4 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_26', 'SHE_27', 'SHE_28', 'SHE_31')_3_4 : 1.0
# r_('SHE_02', 'SHE_20', 'SHE_21')_2_2 : 1.0
# r_('SHE_02', 'SHE_20', 'SHE_21')_4_2 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_07', 'SHE_08')_1_5 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_07', 'SHE_08')_2_5 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_07', 'SHE_08')_3_5 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_07', 'SHE_08')_4_5 : 1.0
# r_('SHE_10', 'SHE_22', 'SHE_24', 'SHE_25')_1_3 : 1.0
# r_('SHE_10', 'SHE_22', 'SHE_24', 'SHE_25')_3_3 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_13', 'SHE_14', 'SHE_18')_1_1 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_13', 'SHE_14', 'SHE_18')_3_1 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_12', 'SHE_15', 'SHE_19')_2_1 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_12', 'SHE_15', 'SHE_19')_4_1 : 1.0
# r_('SHE_02', 'SHE_17')_1_2 : 1.0
# r_('SHE_02', 'SHE_17')_3_2 : 1.0
# r_('SHE_09', 'SHE_16', 'SHE_23')_2_3 : 1.0
# r_('SHE_09', 'SHE_16', 'SHE_23')_4_3 : 1.0
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 1139 rows, 33491 columns and 793896 nonzeros
# Model fingerprint: 0xbc9c7ae6
# Variable types: 20 continuous, 33471 integer (33471 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 642 rows and 3348 columns
# Presolve time: 1.04s
# Presolved: 497 rows, 30143 columns, 531950 nonzeros
# Variable types: 0 continuous, 30143 integer (30094 binary)
#
# Root relaxation: objective 1.655473e+03, 9712 iterations, 2.70 seconds (7.67 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1655.75339    0  185          - 1655.75339      -     -    5s
# H    0     0                    2699.7430000 1655.75339  38.7%     -    5s
# H    0     0                    2290.8950000 1655.75339  27.7%     -    6s
#      0     0 1656.40477    0  195 2290.89500 1656.40477  27.7%     -    8s
#      0     0 1697.84297    0  190 2290.89500 1697.84297  25.9%     -   10s
#      0     0 1697.84297    0  192 2290.89500 1697.84297  25.9%     -   11s
# H    0     0                    2034.7180000 1697.84297  16.6%     -   12s
#      0     0 1697.84297    0  187 2034.71800 1697.84297  16.6%     -   12s
#      0     0 1697.84297    0  202 2034.71800 1697.84297  16.6%     -   12s
#      0     0 1697.84297    0  196 2034.71800 1697.84297  16.6%     -   13s
#      0     0 1697.84297    0  180 2034.71800 1697.84297  16.6%     -   13s
#      0     0 1697.84297    0  154 2034.71800 1697.84297  16.6%     -   14s
# H    0     0                    2032.9850000 1697.84297  16.5%     -   17s
# H    0     2                    2023.8650000 1697.84297  16.1%     -   17s
#      0     2 1697.84297    0  154 2023.86500 1697.84297  16.1%     -   17s
#      1     4 1697.84297    1  169 2023.86500 1697.84297  16.1%  3540   21s
#      7     8 1697.84297    3  176 2023.86500 1697.84297  16.1%  2797   26s
#     21    12 1697.84297    5  189 2023.86500 1697.84297  16.1%  2041   30s
# H   31    16                    2020.2650000 1697.84297  16.0%  1526   33s
#    950   524 3432.99418   15  164 3634.68000 3395.68594  6.58%   261   61s
#   1156   606 3395.68594   14  166 3634.68000 3395.68594  6.58%   257   65s
#   1674   939 3523.07782   50   71 3634.68000 3395.68594  6.58%   222   71s
#   1918   943     cutoff   63      3634.68000 3395.68594  6.58%   204   75s
#   2503  1245 3558.54533   40  183 3634.68000 3395.68594  6.58%   189  121s
#   2506  1247 3490.69737   14  168 3634.68000 3395.68594  6.58%   189  126s
#   2510  1250 3554.99311   52  209 3634.68000 3395.68594  6.58%   189  130s
#   2514  1253 3410.36578   16  174 3634.68000 3408.40457  6.23%   197  140s
#   2516  1254 3441.84631   17  200 3634.68000 3413.23065  6.09%   200  146s
#   2518  1256 3442.90188   18  187 3634.68000 3441.84631  5.31%   201  150s
#   2527  1265 3443.86721   20  197 3634.68000 3443.40599  5.26%   204  155s
#
# Cutting planes:
#   Gomory: 2
#   Clique: 79
#   Flow cover: 1
#   Zero half: 6
#   RLT: 2
#
# Explored 2547 nodes (552243 simplex iterations) in 157.14 seconds (481.26 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 3634.68 3650.56 3651.8 ... 3984.43
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 3.634680000000e+03, best bound 3.474045784784e+03, gap 4.4195%
# obj= 3634.6800000000003
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_26', 'SHE_29')_2_5 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_26', 'SHE_29', 'SHE_31')_4_5 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_27', 'SHE_28', 'SHE_30')_1_5 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_27', 'SHE_28', 'SHE_30')_3_5 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_20')_1_4 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_20')_3_4 : 1.0
# r_('SHE_02', 'SHE_08', 'SHE_10')_2_1 : 1.0
# r_('SHE_02', 'SHE_08', 'SHE_10')_4_1 : 1.0
# r_('SHE_02', 'SHE_08', 'SHE_24')_1_1 : 1.0
# r_('SHE_02', 'SHE_08', 'SHE_24')_3_1 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_21', 'SHE_22')_2_4 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_21', 'SHE_22')_4_4 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_13', 'SHE_19')_1_2 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_13', 'SHE_19')_3_2 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_12', 'SHE_14', 'SHE_15', 'SHE_18')_2_2 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_12', 'SHE_14', 'SHE_15', 'SHE_18')_4_2 : 1.0
# r_('SHE_07', 'SHE_09', 'SHE_25')_1_3 : 1.0
# r_('SHE_07', 'SHE_09', 'SHE_25')_3_3 : 1.0
# r_('SHE_07', 'SHE_16', 'SHE_17', 'SHE_23')_2_3 : 1.0
# r_('SHE_07', 'SHE_16', 'SHE_17', 'SHE_23')_4_3 : 1.0
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 1139 rows, 33491 columns and 793896 nonzeros
# Model fingerprint: 0xd83ffa74
# Variable types: 20 continuous, 33471 integer (33471 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 4e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 642 rows and 3348 columns
# Presolve time: 1.07s
# Presolved: 497 rows, 30143 columns, 531950 nonzeros
# Variable types: 0 continuous, 30143 integer (30094 binary)
#
# Root relaxation: objective 4.966419e+03, 10648 iterations, 3.01 seconds (8.58 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0
#   1665   593 5197.34337   14  217 5408.55000 5092.64228  5.84%   492  131s
#   1943   683 5092.64228    8  221 5408.55000 5092.64228  5.84%   475  136s
#   2212   791 5227.26222   11  102 5408.55000 5092.64228  5.84%   464  140s
#   2551   893 5246.19952    9  194 5408.55000 5092.64228  5.84%   447  146s
#   2872   909 infeasible   22      5408.55000 5092.64228  5.84%   453  151s
#   3281   981 5255.21272   26  119 5408.55000 5130.35316  5.14%   446  157s
#
# Cutting planes:
#   Cover: 7
#   Clique: 87
#   MIR: 4
#   GUB cover: 15
#   Inf proof: 10
#   Zero half: 3
#   RLT: 23
#   Relax-and-lift: 4
#
# Explored 3502 nodes (1567170 simplex iterations) in 157.44 seconds (522.20 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 5408.55 5413.49 5415.31 ... 5890.29
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 5.408550000000e+03, best bound 5.144907645914e+03, gap 4.8745%
# obj= 5408.549999999999
# r_('SHE_01', 'SHE_04', 'SHE_27', 'SHE_30')_1_5 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_27', 'SHE_30')_3_5 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_26', 'SHE_28', 'SHE_29')_4_5 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_26', 'SHE_28', 'SHE_29', 'SHE_31')_2_5 : 1.0
# r_('SHE_02', 'SHE_06', 'SHE_20')_2_4 : 1.0
# r_('SHE_02', 'SHE_06', 'SHE_20')_4_4 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_10')_1_1 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_10')_3_1 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_24')_2_1 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_24')_4_1 : 1.0
# r_('SHE_02', 'SHE_06', 'SHE_21', 'SHE_22')_1_4 : 1.0
# r_('SHE_02', 'SHE_06', 'SHE_21', 'SHE_22')_3_4 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_12', 'SHE_15', 'SHE_18')_2_2 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_12', 'SHE_15', 'SHE_18')_4_2 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_13', 'SHE_14', 'SHE_19')_1_2 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_13', 'SHE_14', 'SHE_19')_3_2 : 1.0
# r_('SHE_07', 'SHE_09', 'SHE_25')_1_3 : 1.0
# r_('SHE_07', 'SHE_09', 'SHE_25')_3_3 : 1.0
# r_('SHE_07', 'SHE_16', 'SHE_17', 'SHE_23')_2_3 : 1.0
# r_('SHE_07', 'SHE_16', 'SHE_17', 'SHE_23')_4_3 : 1.0
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 1139 rows, 33491 columns and 793896 nonzeros
# Model fingerprint: 0xdd8f0360
# Variable types: 20 continuous, 33471 integer (33471 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 6e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 642 rows and 3348 columns
# Presolve time: 1.06s
# Presolved: 497 rows, 30143 columns, 531950 nonzeros
# Variable types: 0 continuous, 30143 integer (30094 binary)
#
# Root relaxation: objective 6.621892e+03, 11355 iterations, 3.25 seconds (9.25 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 
work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 7180.63 7181.55 7198.08 ... 7328.31
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 7.180632000000e+03, best bound 6.829510640452e+03, gap 4.8898%
# obj= 7180.631999999998
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_27', 'SHE_30')_1_2 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_27', 'SHE_30')_3_2 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_26', 'SHE_28', 'SHE_29')_2_2 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_26', 'SHE_28', 'SHE_29', 'SHE_31')_4_2 : 1.0
# r_('SHE_02', 'SHE_20')_2_4 : 1.0
# r_('SHE_02', 'SHE_20')_4_4 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08')_1_1 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08')_3_1 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_10')_2_1 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_10')_4_1 : 1.0
# r_('SHE_02', 'SHE_21', 'SHE_22', 'SHE_24')_1_4 : 1.0
# r_('SHE_02', 'SHE_21', 'SHE_22', 'SHE_24')_3_4 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_18', 'SHE_19')_2_5 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_18', 'SHE_19')_4_5 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_12', 'SHE_13', 'SHE_14', 'SHE_15')_1_5 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_12', 'SHE_13', 'SHE_14', 'SHE_15')_3_5 : 1.0
# r_('SHE_07', 'SHE_09', 'SHE_25')_1_3 : 1.0
# r_('SHE_07', 'SHE_09', 'SHE_25')_3_3 : 1.0
# r_('SHE_07', 'SHE_16', 'SHE_17', 'SHE_23')_2_3 : 1.0
# r_('SHE_07', 'SHE_16', 'SHE_17', 'SHE_23')_4_3 : 1.0
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 1139 rows, 33491 columns and 793896 nonzeros
# Model fingerprint: 0x0a9d6d8c
# Variable types: 20 continuous, 33471 integer (33471 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 7e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 642 rows and 3348 columns
# Presolve time: 1.09s
# Presolved: 497 rows, 30143 columns, 531950 nonzeros
# Variable types: 0 continuous, 30143 integer (30094 binary)
#
# Root relaxation: objective 8.277365e+03, 11008 iterations, 3.09 seconds (8.77 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8278.50531    0  178          - 8278.50531      -     -    5s
# H    0     0                    9026.0050000 8278.50531  8.28%     -    6s
#      0     0 8282.02387    0  187 9026.00500 8282.02387  8.24%     -    7s
# H    0     0                    9002.9100000 8282.02387  8.01%     -    9s
#      0     0 8282.02387    0  189 9002.91000 8282.02387  8.01%     -   10s
# H    0     0                    8997.5250000 8282.02387  7.95%     -   10s
#      0     0 8441.95964    0  193 8997.52500 8441.95964  6.17%     -   11s
#      0     0 8441.95964    0  159 8997.52500 8441.95964  6.17%     -   12s
#      0     0 8442.00319    0  180 8997.52500 8442.00319  6.17%     -   12s
#      0     0 8442.00319    0  193 8997.52500 8442.00319  6.17%     -   12s
#      0     0 8442.00319    0  185 8997.52500 8442.00319  6.17%     -   13s
#      0     0 8442.00319    0  160 8997.52500 8442.00319  6.17%     -   13s
#      0     0 8442.00319    0  179 8997.52500 8442.00319  6.17%     -   14s
#      0     0 8442.00319    0  202 8997.52500 8442.00319  6.17%     -   14s
#      0     0 8442.00319    0  172 8997.52500 8442.00319  6.17%     -   16s
#      0     2 8442.00319    0  161 8997.52500 8442.00319  6.17%     -   20s
: 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_12', 'SHE_14', 'SHE_18')_3_4 : 1.0
# r_('SHE_07', 'SHE_09', 'SHE_25')_2_3 : 1.0
# r_('SHE_07', 'SHE_09', 'SHE_25')_4_3 : 1.0
# r_('SHE_07', 'SHE_16', 'SHE_17', 'SHE_23')_1_3 : 1.0
# r_('SHE_07', 'SHE_16', 'SHE_17', 'SHE_23')_3_3 : 1.0
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 1139 rows, 33491 columns and 793896 nonzeros
# Model fingerprint: 0xc2957e63
# Variable types: 20 continuous, 33471 integer (33471 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 8e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 642 rows and 3348 columns
# Presolve time: 1.11s
# Presolved: 497 rows, 30143 columns, 531950 nonzeros
# Variable types: 0 continuous, 30143 integer (30094 binary)
#
# Root relaxation: objective 9.932839e+03, 9234 iterations, 2.50 seconds (7.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9934.20637    0  175          - 9934.20637      -     -    5s
# H    0     0                    11341.816000 9934.20637  12.4%     -    6s
# H    0     0                    11175.210000 9934.20637  11.1%     -    6s
# H    0     0                    10717.276000 9934.20637  7.31%     -    6s
# H    0     0                    10713.676000 9934.20637  7.28%     -    6s
#      0     0 9938.42865    0  185 10713.6760 9938.42865  7.24%     -    7s
#      0     0 9938.42865    0  184 10713.6760 9938.42865  7.24%     -    9s
#      0     0 10106.5841    0  196 10713.6760 10106.5841  5.67%     -   10s
# H    0     0                    10682.554000 10106.5841  5.39%     -   10s
#      0     0 10106.5841    0  203 10682.5540 10106.5841  5.39%     -   11s
#      0     0 10106.5841    0  172 10682.5540 10106.5841  5.39%     -   12s
#      0     0 10106.5841    0  158 10682.5540 10106.5841  5.39%     -   12s
#      0     0 10106.5841    0  199 10682.5540 10106.5841  5.39%     -   12s
#      0     0 10106.5841    0  161 10682.5540 10106.5841  5.39%     -   14s
# H    0     2                    10675.702000 10106.5841  5.33%     -   17s
#      0     2 10106.5841    0  151 10675.7020 10106.5841  5.33%     -   17s
#      3     6 10106.5841    2  185 10675.7020 10106.5841  5.33%  1920   23s
#      7    10 10533.3928    3  136 10675.7020 10106.5841  5.33%  4411   25s
#     23    19 10661.6945    5   87 10675.7020 10106.5841  5.33%  2223   32s
#     33    27     cutoff    6      10675.7020 10106.5841  5.33%  2024   36s
# H   34    27                    10637.642000 10106.5841  4.99%  1964   36s
#
# Cutting planes:
#   Clique: 57
#   MIR: 12
#   GUB cover: 8
#   Inf proof: 1
#   Zero half: 5
#   RLT: 11
#   Relax-and-lift: 3
#
# Explored 43 nodes (93213 simplex iterations) in 36.60 seconds (108.17 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 7: 10637.6 10675.7 10682.6 ... 11341.8
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 1.063764200000e+04, best bound 1.010658407038e+04, gap 4.9923%
# obj= 10637.642000000003
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_07', 'SHE_26')_2_5 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_07', 'SHE_26', 'SHE_31')_4_5 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_07', 'SHE_27', 'SHE_28', 'SHE_29', 'SHE_30')_1_5 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_07', 'SHE_27', 'SHE_28', 'SHE_29', 'SHE_30')_3_5 : 1.0
# r_('SHE_02', 'SHE_20', 'SHE_24')_1_1 : 1.0
# r_('SHE_02', 'SHE_20', 'SHE_24')_3_1 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_10', 'SHE_22')_1_4 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_10', 'SHE_22')_3_4 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_21', 'SHE_25')_2_4 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_21', 'SHE_25')_4_4 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_14', 'SHE_18')_2_2 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_14', 'SHE_18')_4_2 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_12', 'SHE_13', 'SHE_15', 'SHE_19')_1_2 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_12', 'SHE_13', 'SHE_15', 'SHE_19')_3_2 : 1.0
# r_('SHE_02', 'SHE_09')_2_1 : 1.0
# r_('SHE_02', 'SHE_09')_4_1 : 1.0
# r_('SHE_16', 'SHE_17', 'SHE_23')_2_3 : 1.0
# r_('SHE_16', 'SHE_17', 'SHE_23')_4_3 : 1.0
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 1139 rows, 33491 columns and 793896 nonzeros
# Model fingerprint: 0x1c5c851f
# Variable types: 20 continuous, 33471 integer (33471 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 642 rows and 3348 columns
# Presolve time: 1.15s
# Presolved: 497 rows, 30143 columns, 531950 nonzeros
# Variable types: 0 continuous, 30143 integer (30094 binary)
#
# Root relaxation: objective 1.158418e+04, 8761 iterations, 2.52 seconds (6.98 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11585.3116    0  166          - 11585.3116      -     -    4s
# H    0     0                    12357.723000 11585.3116  6.25%     -    5s
#      0     0 11591.2337    0  155 12357.7230 11591.2337  6.20%     -    7s
#      0     0 11591.2337    0  187 12357.7230 11591.2337  6.20%     -    8s
#      0     0 11591.2337    0  179 12357.7230 11591.2337  6.20%     -    9s
# H    0     0                    12302.237000 11593.6819  5.76%     -   10s
#      0     0 11593.6819    0  141 12302.2370 11593.6819  5.76%     -   10s
# H    0     0                    12298.637000 11593.6819  5.73%     -   12s
#      0     0 11593.6819    0  179 12298.6370 11593.6819  5.73%     -   12s
#      0     0 11593.6819    0  189 12298.6370 11593.6819  5.73%     -   12s
#      0     0 11767.4408    0  186 12298.6370 11767.4408  4.32%     -   13s
#
# Cutting planes:
#   Clique: 44
#   MIR: 2
#   GUB cover: 2
#   Zero half: 2
#   RLT: 9
#   Relax-and-lift: 2
#
# Explored 1 nodes (15809 simplex iterations) in 13.20 seconds (24.93 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 3: 12298.6 12302.2 12357.7
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 1.229863700000e+04, best bound 1.176744077939e+04, gap 4.3191%
# obj= 12298.636999999997
# r_('SHE_01', 'SHE_04', 'SHE_07', 'SHE_26')_2_1 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_07', 'SHE_26', 'SHE_31')_4_1 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_07', 'SHE_27', 'SHE_28', 'SHE_29', 'SHE_30')_1_1 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_07', 'SHE_27', 'SHE_28', 'SHE_29', 'SHE_30')_3_1 : 1.0
# r_('SHE_02', 'SHE_20', 'SHE_24')_2_2 : 1.0
# r_('SHE_02', 'SHE_20', 'SHE_24')_4_2 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_06', 'SHE_08', 'SHE_10', 'SHE_22')_2_5 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_06', 'SHE_08', 'SHE_10', 'SHE_22')_4_5 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_06', 'SHE_08', 'SHE_21', 'SHE_25')_1_5 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_06', 'SHE_08', 'SHE_21', 'SHE_25')_3_5 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_14', 'SHE_18')_2_4 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_14', 'SHE_18')_4_4 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_12', 'SHE_13', 'SHE_15', 'SHE_19')_1_4 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_12', 'SHE_13', 'SHE_15', 'SHE_19')_3_4 : 1.0
# r_('SHE_02', 'SHE_09')_1_2 : 1.0
# r_('SHE_02', 'SHE_09')_3_2 : 1.0
# r_('SHE_16', 'SHE_17', 'SHE_23')_2_3 : 1.0
# r_('SHE_16', 'SHE_17', 'SHE_23')_4_3 : 1.0
# Set parameter MIPGap to value 0.05
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
# Optimize a model with 1139 rows, 33491 columns and 793896 nonzeros
# Model fingerprint: 0x4353d780
# Variable types: 20 continuous, 33471 integer (33471 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 642 rows and 3348 columns
# Presolve time: 1.07s
# Presolved: 497 rows, 30143 columns, 531950 nonzeros
# Variable types: 0 continuous, 30143 integer (30094 binary)
#
# Root relaxation: objective 1.323389e+04, 8354 iterations, 2.33 seconds (6.46 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 13233.8883    0  128          - 13233.8883      -     -    4s
# H    0     0                    14281.188000 13233.8883  7.33%     -    4s
# H    0     0                    14279.388000 13233.8883  7.32%     -    4s
#      0     0 13233.8883    0  178 14279.3880 13233.8883  7.32%     -    5s
# H    0     0                    14275.788000 13233.8883  7.30%     -    6s
#      0     0 13233.8883    0  128 14275.7880 13233.8883  7.30%     -    7s
# H    0     0                    14098.464000 13233.8883  6.13%     -    7s
# H    0     0                    14019.392000 13233.8883  5.60%     -    8s
#      0     0 13233.8883    0  144 14019.3920 13233.8883  5.60%     -    9s
#      0     0 13233.8883    0  169 14019.3920 13233.8883  5.60%     -    9s
#      0     0 13420.0005    0  147 14019.3920 13420.0005  4.28%     -    9s
#
# Cutting planes:
#   Clique: 49
#   MIR: 6
#   Zero half: 2
#   RLT: 22
#
# Explored 1 nodes (15292 simplex iterations) in 9.97 seconds (18.59 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 5: 14019.4 14098.5 14275.8 ... 14281.2
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 1.401939200000e+04, best bound 1.342000052279e+04, gap 4.2754%
# obj= 14019.391999999994
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_07', 'SHE_26')_3_2 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_07', 'SHE_26', 'SHE_31')_1_2 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_07', 'SHE_27', 'SHE_28', 'SHE_29', 'SHE_30')_2_2 : 1.0
# r_('SHE_01', 'SHE_04', 'SHE_06', 'SHE_07', 'SHE_27', 'SHE_28', 'SHE_29', 'SHE_30')_4_2 : 1.0
# r_('SHE_02', 'SHE_20', 'SHE_24')_1_4 : 1.0
# r_('SHE_02', 'SHE_20', 'SHE_24')_3_4 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_10', 'SHE_22')_2_1 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_10', 'SHE_22')_4_1 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_21', 'SHE_25')_1_1 : 1.0
# r_('SHE_02', 'SHE_05', 'SHE_08', 'SHE_21', 'SHE_25')_3_1 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_12', 'SHE_18')_1_5 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_11', 'SHE_12', 'SHE_18')_3_5 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_13', 'SHE_14', 'SHE_15', 'SHE_19')_2_5 : 1.0
# r_('SHE_01', 'SHE_03', 'SHE_13', 'SHE_14', 'SHE_15', 'SHE_19')_4_5 : 1.0
# r_('SHE_02', 'SHE_09')_2_4 : 1.0
# r_('SHE_02', 'SHE_09')_4_4 : 1.0
# r_('SHE_16', 'SHE_17', 'SHE_23')_1_3 : 1.0
# r_('SHE_16', 'SHE_17', 'SHE_23')_3_3 : 1.0

# %%
dfs[2]
# Out:
#                                                                                                        \
# (Roads/ Days,)                                                                                 [ day1
# (SHE_01,)
# (SHE_02,)                                                                                        80.3
# (SHE_03,)
# (SHE_04,)
# (SHE_05,)
# (SHE_06,)
# (SHE_07,)
# (SHE_08,)                                                                                        1.14
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)
# (SHE_13,)
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)
# (SHE_24,)                                                                                       24.73
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                               106.17
# Daily_driving_distance                                                                        230.441
# Daily visiting Locations (Shortest Distance route)                         [(SHE_02, SHE_08, SHE_24)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.38187, 145.39911...
#
#                                                                                                        \
# (Roads/ Days,)                                                                                   day2
# (SHE_01,)                                                                                        15.5
# (SHE_02,)
# (SHE_03,)                                                                                        34.3
# (SHE_04,)
# (SHE_05,)
# (SHE_06,)
# (SHE_07,)
# (SHE_08,)
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)                                                                                        11.6
# (SHE_12,)
# (SHE_13,)                                                                                       28.49
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)
# (SHE_19,)                                                                                        11.9
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                               101.79
# Daily_driving_distance                                                                        166.667
# Daily visiting Locations (Shortest Distance route)         [(SHE_01, SHE_13, SHE_11, SHE_19, SHE_03)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.38187, 145.39911...
#
#                                                                                                    W1  \
# (Roads/ Days,)                                                                                   day3
# (SHE_01,)
# (SHE_02,)
# (SHE_03,)
# (SHE_04,)
# (SHE_05,)
# (SHE_06,)
# (SHE_07,)                                                                                       18.93
# (SHE_08,)
# (SHE_09,)                                                                                       51.95
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)
# (SHE_13,)
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)
# (SHE_24,)
# (SHE_25,)                                                                                        31.6
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                               102.48
# Daily_driving_distance                                                                        191.471
# Daily visiting Locations (Shortest Distance route)                         [(SHE_09, SHE_25, SHE_07)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.17442, 145.11939...
#
#                                                                                                        \
# (Roads/ Days,)                                                                                   day4
# (SHE_01,)
# (SHE_02,)                                                                                        80.3
# (SHE_03,)
# (SHE_04,)
# (SHE_05,)                                                                                        2.76
# (SHE_06,)
# (SHE_07,)
# (SHE_08,)
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)
# (SHE_13,)
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)
# (SHE_19,)
# (SHE_20,)                                                                                       18.08
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                               101.14
# Daily_driving_distance                                                                        177.678
# Daily visiting Locations (Shortest Distance route)                         [(SHE_20, SHE_05, SHE_02)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.06994, 145.68326...
#
#                                                                                                        \
# (Roads/ Days,)                                                                                day5  ]
# (SHE_01,)                                                                                        15.5
# (SHE_02,)
# (SHE_03,)
# (SHE_04,)                                                                                        29.1
# (SHE_05,)
# (SHE_06,)                                                                                        5.46
# (SHE_07,)
# (SHE_08,)
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)
# (SHE_13,)
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)                                                                                        9.03
# (SHE_28,)                                                                                       13.65
# (SHE_29,)
# (SHE_30,)                                                                                       27.09
# (SHE_31,)
# Daily_inspection                                                                                99.83
# Daily_driving_distance                                                                        159.199
# Daily visiting Locations (Shortest Distance route)  [(SHE_30, SHE_27, SHE_28, SHE_01, SHE_04, SHE_...
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.39503, 145.35585...
#
#                                                                                                        \
# (Roads/ Days,)                                                                                 [ day1
# (SHE_01,)
# (SHE_02,)                                                                                        80.3
# (SHE_03,)
# (SHE_04,)
# (SHE_05,)
# (SHE_06,)
# (SHE_07,)
# (SHE_08,)                                                                                        1.14
# (SHE_09,)
# (SHE_10,)                                                                                        41.4
# (SHE_11,)
# (SHE_12,)
# (SHE_13,)
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                               122.84
# Daily_driving_distance                                                                        221.801
# Daily visiting Locations (Shortest Distance route)                         [(SHE_02, SHE_10, SHE_08)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.38187, 145.39911...
#
#                                                                                                        \
# (Roads/ Days,)                                                                                   day2
# (SHE_01,)                                                                                        15.5
# (SHE_02,)
# (SHE_03,)                                                                                        34.3
# (SHE_04,)
# (SHE_05,)
# (SHE_06,)
# (SHE_07,)
# (SHE_08,)
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)                                                                                        11.6
# (SHE_13,)
# (SHE_14,)                                                                                         2.9
# (SHE_15,)                                                                                        15.2
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)                                                                                       20.18
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                                99.68
# Daily_driving_distance                                                                        158.183
# Daily visiting Locations (Shortest Distance route)  [(SHE_03, SHE_12, SHE_15, SHE_14, SHE_18, SHE_...
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.38102, 145.39924...
#
#                                                                                                    W2  \
# (Roads/ Days,)                                                                                   day3
# (SHE_01,)
# (SHE_02,)
# (SHE_03,)
# (SHE_04,)
# (SHE_05,)
# (SHE_06,)
# (SHE_07,)                                                                                       18.93
# (SHE_08,)
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)
# (SHE_13,)
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)                                                                                       34.05
# (SHE_17,)                                                                                       24.84
# (SHE_18,)
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)                                                                                        21.5
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                                99.32
# Daily_driving_distance                                                                        162.638
# Daily visiting Locations (Shortest Distance route)                 [(SHE_16, SHE_17, SHE_23, SHE_07)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.33554, 145.40255...
#
#                                                                                                        \
# (Roads/ Days,)                                                                                   day4
# (SHE_01,)
# (SHE_02,)                                                                                        80.3
# (SHE_03,)
# (SHE_04,)
# (SHE_05,)                                                                                        2.76
# (SHE_06,)
# (SHE_07,)
# (SHE_08,)
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)
# (SHE_13,)
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)                                                                                        7.03
# (SHE_22,)                                                                                        7.12
# (SHE_23,)
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                                97.21
# Daily_driving_distance                                                                         173.59
# Daily visiting Locations (Shortest Distance route)                 [(SHE_22, SHE_05, SHE_21, SHE_02)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-35.98925, 145.6317)...
#
#                                                                                                        \
# (Roads/ Days,)                                                                                day5  ]
# (SHE_01,)                                                                                        15.5
# (SHE_02,)
# (SHE_03,)
# (SHE_04,)                                                                                        29.1
# (SHE_05,)
# (SHE_06,)                                                                                        5.46
# (SHE_07,)
# (SHE_08,)
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)
# (SHE_13,)
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)                                                                                       22.74
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)                                                                                       20.22
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                                93.02
# Daily_driving_distance                                                                        137.142
# Daily visiting Locations (Shortest Distance route)         [(SHE_29, SHE_01, SHE_04, SHE_26, SHE_06)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.44768, 145.43181...
#
#                                                                                                        \
# (Roads/ Days,)                                                                                 [ day1
# (SHE_01,)
# (SHE_02,)                                                                                        80.3
# (SHE_03,)
# (SHE_04,)
# (SHE_05,)
# (SHE_06,)
# (SHE_07,)
# (SHE_08,)                                                                                        1.14
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)
# (SHE_13,)
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)
# (SHE_24,)                                                                                       24.73
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                               106.17
# Daily_driving_distance                                                                        230.441
# Daily visiting Locations (Shortest Distance route)                         [(SHE_02, SHE_08, SHE_24)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.38187, 145.39911...
#
#                                                                                                        \
# (Roads/ Days,)                                                                                   day2
# (SHE_01,)                                                                                        15.5
# (SHE_02,)
# (SHE_03,)                                                                                        34.3
# (SHE_04,)
# (SHE_05,)
# (SHE_06,)
# (SHE_07,)
# (SHE_08,)
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)                                                                                        11.6
# (SHE_12,)
# (SHE_13,)                                                                                       28.49
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)
# (SHE_19,)                                                                                        11.9
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                               101.79
# Daily_driving_distance                                                                        166.667
# Daily visiting Locations (Shortest Distance route)         [(SHE_01, SHE_13, SHE_11, SHE_19, SHE_03)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.38187, 145.39911...
#
#                                                                                                    W3  \
# (Roads/ Days,)                                                                                   day3
# (SHE_01,)
# (SHE_02,)
# (SHE_03,)
# (SHE_04,)
# (SHE_05,)
# (SHE_06,)
# (SHE_07,)                                                                                       18.93
# (SHE_08,)
# (SHE_09,)                                                                                       51.95
# (SHE_10,)
# (SHE_11,)
# ...
# Daily_inspection                                                                               122.84
# Daily_driving_distance                                                                        221.801
# Daily visiting Locations (Shortest Distance route)                         [(SHE_02, SHE_10, SHE_08)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.38187, 145.39911...
#
#                                                                                                        \
# (Roads/ Days,)                                                                                   day2
# (SHE_01,)                                                                                        15.5
# (SHE_02,)
# (SHE_03,)                                                                                        34.3
# (SHE_04,)
# (SHE_05,)
# (SHE_06,)
# (SHE_07,)
# (SHE_08,)
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)                                                                                        11.6
# (SHE_13,)
# (SHE_14,)                                                                                         2.9
# (SHE_15,)                                                                                        15.2
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)                                                                                       20.18
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                                99.68
# Daily_driving_distance                                                                        158.183
# Daily visiting Locations (Shortest Distance route)  [(SHE_03, SHE_12, SHE_15, SHE_14, SHE_18, SHE_...
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.38102, 145.39924...
#
#                                                                                                    W4  \
# (Roads/ Days,)                                                                                   day3
# (SHE_01,)
# (SHE_02,)
# (SHE_03,)
# (SHE_04,)
# (SHE_05,)
# (SHE_06,)
# (SHE_07,)                                                                                       18.93
# (SHE_08,)
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)
# (SHE_13,)
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)                                                                                       34.05
# (SHE_17,)                                                                                       24.84
# (SHE_18,)
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)                                                                                        21.5
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                                99.32
# Daily_driving_distance                                                                        162.638
# Daily visiting Locations (Shortest Distance route)                 [(SHE_16, SHE_17, SHE_23, SHE_07)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.33554, 145.40255...
#
#                                                                                                        \
# (Roads/ Days,)                                                                                   day4
# (SHE_01,)
# (SHE_02,)                                                                                        80.3
# (SHE_03,)
# (SHE_04,)
# (SHE_05,)                                                                                        2.76
# (SHE_06,)
# (SHE_07,)
# (SHE_08,)
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)
# (SHE_13,)
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)                                                                                        7.03
# (SHE_22,)                                                                                        7.12
# (SHE_23,)
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)
# (SHE_30,)
# (SHE_31,)
# Daily_inspection                                                                                97.21
# Daily_driving_distance                                                                         173.59
# Daily visiting Locations (Shortest Distance route)                 [(SHE_22, SHE_05, SHE_21, SHE_02)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-35.98925, 145.6317)...
#
#
# (Roads/ Days,)                                                                                day5  ]
# (SHE_01,)                                                                                        15.5
# (SHE_02,)
# (SHE_03,)
# (SHE_04,)                                                                                        29.1
# (SHE_05,)
# (SHE_06,)                                                                                        5.46
# (SHE_07,)
# (SHE_08,)
# (SHE_09,)
# (SHE_10,)
# (SHE_11,)
# (SHE_12,)
# (SHE_13,)
# (SHE_14,)
# (SHE_15,)
# (SHE_16,)
# (SHE_17,)
# (SHE_18,)
# (SHE_19,)
# (SHE_20,)
# (SHE_21,)
# (SHE_22,)
# (SHE_23,)
# (SHE_24,)
# (SHE_25,)
# (SHE_26,)                                                                                       22.74
# (SHE_27,)
# (SHE_28,)
# (SHE_29,)                                                                                       20.22
# (SHE_30,)
# (SHE_31,)                                                                                         3.6
# Daily_inspection                                                                                93.02
# Daily_driving_distance                                                                        137.142
# Daily visiting Locations (Shortest Distance route)         [(SHE_29, SHE_01, SHE_04, SHE_26, SHE_06)]
# Location Coordinates                                [[(-36.3782, 145.41881), (-36.44768, 145.43181...

# %%
for i in range(len(total_driving_distance_weight)):
    dfs[i].to_excel('/Users/kuan/Desktop/Downer Project Final/Schedule Results/N_result('+str(i+1)+').xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kuan/Desktop/Downer Project Final/Optimize Routes.ipynb Cell 42 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> for i in range(len(total_driving_distance_weight)):
#       <a href='vscode-notebook-cell:/Users/kuan/Desktop/Downer%20Project%20Final/Optimize%20Routes.ipynb#X56sZmlsZQ%3D%3D?line=1'>2</a>     dfs[i].to_excel('/Users/kuan/Desktop/Downer Project Final/Schedule Results/result('+str(i+1)+').xlsx')
#
# NameError: name 'total_driving_distance_weight' is not defined
